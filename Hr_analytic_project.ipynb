# %%
import pandas as pd

# %%
df = pd.read_csv('hr_analytics_messy_dataset.csv')
df
# Out:
#       Employee_ID  Age Department    JobRole  Monthly_Income  \
# 0               1   56    Finance    Manager           92214
# 1               2   46         HR    Analyst           47052
# 2               3   32  Marketing  Executive           67769
# 3               4   25      Sales    Analyst           56032
# 4               5   38         HR      Clerk           98721
# ...           ...  ...        ...        ...             ...
# 1995         1996   43      Sales   Engineer           73767
# 1996         1997   42    Finance  Executive           36469
# 1997         1998   47    Finance   Engineer           11313
# 1998         1999   28  Marketing    Manager           17847
# 1999         2000   24         IT   Engineer           60222
#
#       Years_At_Company  Gender Attrition Age_Group Experience_Level  \
# 0                   14    Male       Yes     46-60           Senior
# 1                   10    Male        No     46-60              Mid
# ...

# %%
df.head()
# Out:
#    Employee_ID  Age Department    JobRole  Monthly_Income  Years_At_Company  \
# 0            1   56    Finance    Manager           92214                14
# 1            2   46         HR    Analyst           47052                10
# 2            3   32  Marketing  Executive           67769                 0
# 3            4   25      Sales    Analyst           56032                17
# 4            5   38         HR      Clerk           98721                11
#
#    Gender Attrition Age_Group Experience_Level  Attrition_Flag Salary_Category
# 0    Male       Yes     46-60           Senior               1            High
# 1    Male        No     46-60              Mid               0          Medium
# 2  Female        No     26-35              New               0            High
# 3  Female       Yes     18-25           Senior               1          Medium
# 4  Female        No     36-45           Senior               0            High

# %%
df.tail()
# Out:
#       Employee_ID  Age Department    JobRole  Monthly_Income  \
# 1995         1996   43      Sales   Engineer           73767
# 1996         1997   42    Finance  Executive           36469
# 1997         1998   47    Finance   Engineer           11313
# 1998         1999   28  Marketing    Manager           17847
# 1999         2000   24         IT   Engineer           60222
#
#       Years_At_Company  Gender Attrition Age_Group Experience_Level  \
# 1995                18  Female        No     36-45           Senior
# 1996                 4    Male        No     36-45           Junior
# 1997                 6  Female        No     46-60              Mid
# 1998                13  Female        No     26-35           Senior
# 1999                 2    Male        No     18-25              New
#
#       Attrition_Flag Salary_Category
# 1995               0            High
# 1996               0          Medium
# 1997               0             Low
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Employee_ID       2000 non-null   int64
#  1   Age               2000 non-null   int64
#  2   Department        2000 non-null   object
#  3   JobRole           2000 non-null   object
#  4   Monthly_Income    2000 non-null   int64
#  5   Years_At_Company  2000 non-null   int64
#  6   Gender            2000 non-null   object
#  7   Attrition         2000 non-null   object
#  8   Age_Group         1954 non-null   object
#  9   Experience_Level  2000 non-null   object
#  10  Attrition_Flag    2000 non-null   int64
#  11  Salary_Category   2000 non-null   object
# dtypes: int64(5), object(7)
# memory usage: 187.6+ KB

# %%
df.describe()
# Out:
#        Employee_ID          Age  Monthly_Income  Years_At_Company  \
# count  2000.000000  2000.000000     2000.000000       2000.000000
# mean   1000.500000    38.744000    55540.623000          9.539000
# std     577.494589    11.744805    25572.797337          5.772273
# min       1.000000    18.000000    10060.000000          0.000000
# 25%     500.750000    29.000000    34360.750000          5.000000
# 50%    1000.500000    39.000000    55371.000000         10.000000
# 75%    1500.250000    49.000000    77292.500000         15.000000
# max    2000.000000    59.000000    99941.000000         19.000000
#
#        Attrition_Flag
# count     2000.000000
# mean         0.292500
# std          0.455024
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000

# %%
df.isnull().sum()
# Out:
# Employee_ID          0
# Age                  0
# Department           0
# JobRole              0
# Monthly_Income       0
# Years_At_Company     0
# Gender               0
# Attrition            0
# Age_Group           46
# Experience_Level     0
# Attrition_Flag       0
# Salary_Category      0
# dtype: int64

# %%
df= df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.loc[:,"Age"] = df["Age"].fillna(df["Age"].median())

# %%
df.loc[:,"Monthly_Income"] = df["Monthly_Income"].fillna(df["Monthly_Income"].median())

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Age', 'Department', 'JobRole', 'Monthly_Income',
#        'Years_At_Company', 'Gender', 'Attrition', 'Age_Group',
#        'Experience_Level', 'Attrition_Flag', 'Salary_Category'],
#       dtype='object')

# %%
df["Age"].isnull().sum()
# Out:
# np.int64(0)

# %%
df.loc[:,'Age'] = df['Age'].astype(int)

# %%
df.dtypes
# Out:
# Employee_ID          int64
# Age                  int64
# Department          object
# JobRole             object
# Monthly_Income       int64
# Years_At_Company     int64
# Gender              object
# Attrition           object
# Age_Group           object
# Experience_Level    object
# Attrition_Flag       int64
# Salary_Category     object
# dtype: object

# %%
df['Department'].unique()
# Out:
# array(['Finance', 'HR', 'Marketing', 'Sales', 'IT', 'Unknown'],
#       dtype=object)

# %%
import numpy as np

# %%
df.loc[:,'Department'] = df['Department'].replace('NAN', np.nan)

# %%
df['Department'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.loc[:,'Department'] = df['Department'].fillna('Unknown')

# %%
df.loc[:,'Department'] = df['Department'].str.strip().str.capitalize()

# %%
df.loc[:,'Department'] = df['Department'].replace({
    'It' : 'IT',
    'Hr' : 'HR'})

# %%
import numpy as np

df.loc[:,'Department'] = df['Department'].replace('Nan', np.nan)

# %%
df['JobRole'].unique()
# Out:
# array(['Manager', 'Analyst', 'Executive', 'Clerk', 'Engineer'],
#       dtype=object)

# %%
df.loc[:,'JobRole'] = df['JobRole'].str.strip().str.capitalize()

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df.loc[:,'Gender'] = df['Gender'].str.strip().str.capitalize()

# %%
df.loc[:,'Gender'] = df['Gender'].replace({
    'F' : 'Female',
    'M' : 'Male'})

# %%
df.head(100)
# Out:
#     Employee_ID  Age Department    JobRole  Monthly_Income  Years_At_Company  \
# 0             1   56    Finance    Manager           92214                14
# 1             2   46         HR    Analyst           47052                10
# 2             3   32  Marketing  Executive           67769                 0
# 3             4   25      Sales    Analyst           56032                17
# 4             5   38         HR      Clerk           98721                11
# ..          ...  ...        ...        ...             ...               ...
# 95           96   59  Marketing    Analyst           43302                15
# 96           97   56         HR    Analyst           95382                 1
# 97           98   58         IT      Clerk           14011                11
# 98           99   45    Finance   Engineer           29782                 5
# 99          100   39    Unknown    Manager           55371                10
#
# ...

# %%
df['Attrition'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df.loc[:,'Age_Group'] = pd.cut(df['Age'],
                               bins = [18,25,35,45,60],
                               labels = ['18-25', '26-35','36-45', '46-60'])

# %%
df.loc[:,'Salary_Category'] = pd.cut(df['Monthly_Income'],
                                     bins = [0,30000,60000,100000],
                                     labels= ['Low','Medium','High'])

# %%
df['Experience_Level'] = pd.cut(df['Years_At_Company'],
                               bins=[-1,2,5,10,20],
                               labels=['New','Junior','Mid','Senior'])

# %%
df.head(100)
# Out:
#     Employee_ID  Age Department    JobRole  Monthly_Income  Years_At_Company  \
# 0             1   56    Finance    Manager           92214                14
# 1             2   46         HR    Analyst           47052                10
# 2             3   32  Marketing  Executive           67769                 0
# 3             4   25      Sales    Analyst           56032                17
# 4             5   38         HR      Clerk           98721                11
# ..          ...  ...        ...        ...             ...               ...
# 95           96   59  Marketing    Analyst           43302                15
# 96           97   56         HR    Analyst           95382                 1
# 97           98   58         IT      Clerk           14011                11
# 98           99   45    Finance   Engineer           29782                 5
# 99          100   39    Unknown    Manager           55371                10
#
# ...

# %%
df['Age'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Age'].unique()
# Out:
# array([56, 46, 32, 25, 38, 36, 40, 28, 41, 53, 57, 20, 39, 19, 47, 55, 50,
#        29, 42, 44, 59, 45, 54, 24, 26, 35, 21, 31, 43, 37, 52, 34, 23, 51,
#        27, 33, 58, 18, 22, 30, 49, 48])

# %%
df['Age'] = df['Age'].fillna(df['Age'].median()).astype(int)

# %%
df.dtypes
# Out:
# Employee_ID            int64
# Age                    int64
# Department            object
# JobRole               object
# Monthly_Income         int64
# Years_At_Company       int64
# Gender                object
# Attrition             object
# Age_Group             object
# Experience_Level    category
# Attrition_Flag         int64
# Salary_Category       object
# dtype: object

# %%
df.loc[:,'Attrition_Flag'] = df['Attrition'].map({'Yes' : 1, 'No' : 0 })

# %%
df['Attrition_Flag'] = df['Attrition_Flag'].astype(int)

# %%
del df['Salary_category']

# %%
df['Monthly_Income']  = df['Monthly_Income'].astype(int)

# %%
df.to_csv('hr_analytics_messy_dataset.csv', index = False)
